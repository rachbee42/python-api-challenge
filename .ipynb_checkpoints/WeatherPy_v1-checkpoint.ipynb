# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")

###QUERY### Number of cities in the list: 623 based on starter code - retunring 594
# Out:
# Number of cities in the list: 581

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
###example APR call: https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API key}
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    #######check aginst https://openweathermap.org/current
    
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()  

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | colby
# Processing Record 2 of Set 1 | ta`u
# Processing Record 3 of Set 1 | puerto natales
# Processing Record 4 of Set 1 | bardai
# Processing Record 5 of Set 1 | georgetown
# Processing Record 6 of Set 1 | blackmans bay
# Processing Record 7 of Set 1 | port-aux-francais
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | badger
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | hawaiian paradise park
# Processing Record 12 of Set 1 | tsumeb
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 15 of Set 1 | castelo do piaui
# Processing Record 16 of Set 1 | ribeira grande
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | enewetak
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | colonia
# Processing Record 21 of Set 1 | grytviken
# Processing Record 22 of Set 1 | tuy hoa
# Processing Record 23 of Set 1 | aldinga beach
# Processing Record 24 of Set 1 | waitangi
# Processing Record 25 of Set 1 | avarua
# Processing Record 26 of Set 1 | patong
# Processing Record 27 of Set 1 | grand falls-windsor
# Processing Record 28 of Set 1 | nuuk
# Processing Record 29 of Set 1 | filey
# Processing Record 30 of Set 1 | keflavik
# Processing Record 31 of Set 1 | chifeng
# Processing Record 32 of Set 1 | isafjordur
# Processing Record 33 of Set 1 | fale old settlement
# Processing Record 34 of Set 1 | port mathurin
# Processing Record 35 of Set 1 | gaspe
# Processing Record 36 of Set 1 | bethel
# Processing Record 37 of Set 1 | margaret river
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | invercargill
# Processing Record 40 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 41 of Set 1 | vilyuchinsk
# Processing Record 42 of Set 1 | bilibino
# Processing Record 43 of Set 1 | adamstown
# Processing Record 44 of Set 1 | isangel
# Processing Record 45 of Set 1 | kirakira
# Processing Record 46 of Set 1 | west island
# Processing Record 47 of Set 1 | vila velha
# Processing Record 48 of Set 1 | okhotsk
# Processing Record 49 of Set 1 | codrington
# Processing Record 50 of Set 1 | khandyga
# Processing Record 0 of Set 2 | dzhalil'
# Processing Record 1 of Set 2 | labuan lombok
# City not found. Skipping...
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | constantia
# Processing Record 4 of Set 2 | tura
# Processing Record 5 of Set 2 | magadan
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | manokwari
# Processing Record 8 of Set 2 | holualoa
# Processing Record 9 of Set 2 | minas de marcona
# Processing Record 10 of Set 2 | alofi
# Processing Record 11 of Set 2 | pisco
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | carhuaz
# Processing Record 15 of Set 2 | launceston
# Processing Record 16 of Set 2 | kulhudhuffushi
# Processing Record 17 of Set 2 | ust-nera
# Processing Record 18 of Set 2 | ocean shores
# Processing Record 19 of Set 2 | manturovo
# Processing Record 20 of Set 2 | afaahiti
# Processing Record 21 of Set 2 | ko pha ngan
# Processing Record 22 of Set 2 | katsuren-haebaru
# Processing Record 23 of Set 2 | xinghua
# Processing Record 24 of Set 2 | vorgashor
# Processing Record 25 of Set 2 | fortuna
# Processing Record 26 of Set 2 | warud
# Processing Record 27 of Set 2 | urangan
# Processing Record 28 of Set 2 | buka
# Processing Record 29 of Set 2 | ceeldheer
# Processing Record 30 of Set 2 | carnarvon
# Processing Record 31 of Set 2 | aasiaat
# Processing Record 32 of Set 2 | tiksi
# Processing Record 33 of Set 2 | cadale
# Processing Record 34 of Set 2 | crane
# Processing Record 35 of Set 2 | newman
# Processing Record 36 of Set 2 | witu
# Processing Record 37 of Set 2 | hinton
# Processing Record 38 of Set 2 | san antonio de pale
# Processing Record 39 of Set 2 | ilulissat
# Processing Record 40 of Set 2 | flying fish cove
# Processing Record 41 of Set 2 | chonchi
# Processing Record 42 of Set 2 | dindima
# Processing Record 43 of Set 2 | cabedelo
# Processing Record 44 of Set 2 | olonkinbyen
# Processing Record 45 of Set 2 | kapa'a
# Processing Record 46 of Set 2 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | klyuchi
# Processing Record 48 of Set 2 | itoman
# Processing Record 49 of Set 2 | ban phe
# City not found. Skipping...
# Processing Record 0 of Set 3 | palikir - national government center
# Processing Record 1 of Set 3 | gazipasa
# Processing Record 2 of Set 3 | vikhorevka
# Processing Record 3 of Set 3 | atafu village
# Processing Record 4 of Set 3 | kyren
# Processing Record 5 of Set 3 | plymouth
# Processing Record 6 of Set 3 | sonsorol village
# City not found. Skipping...
# Processing Record 7 of Set 3 | nagqu
# Processing Record 8 of Set 3 | whitehorse
# Processing Record 9 of Set 3 | walvis bay
# Processing Record 10 of Set 3 | college
# Processing Record 11 of Set 3 | ola
# Processing Record 12 of Set 3 | hobyo
# Processing Record 13 of Set 3 | sitka
# Processing Record 14 of Set 3 | san isidro de curuguaty
# Processing Record 15 of Set 3 | pacific grove
# Processing Record 16 of Set 3 | mount gambier
# Processing Record 17 of Set 3 | polyarnyy
# Processing Record 18 of Set 3 | miri
# Processing Record 19 of Set 3 | tolanaro
# Processing Record 20 of Set 3 | saudarkrokur
# Processing Record 21 of Set 3 | acarau
# Processing Record 22 of Set 3 | paragominas
# Processing Record 23 of Set 3 | saksaul'skiy
# City not found. Skipping...
# Processing Record 24 of Set 3 | saint-joseph
# Processing Record 25 of Set 3 | bredasdorp
# Processing Record 26 of Set 3 | nicoya
# Processing Record 27 of Set 3 | lamu
# Processing Record 28 of Set 3 | santiago de cao
# Processing Record 29 of Set 3 | villa gesell
# Processing Record 30 of Set 3 | igrim
# Processing Record 31 of Set 3 | rongelap
# Processing Record 32 of Set 3 | saint-pierre
# Processing Record 33 of Set 3 | qaqortoq
# Processing Record 34 of Set 3 | vanimo
# Processing Record 35 of Set 3 | homer
# Processing Record 36 of Set 3 | hamilton
# Processing Record 37 of Set 3 | bathsheba
# Processing Record 38 of Set 3 | luderitz
# Processing Record 39 of Set 3 | gbongan
# Processing Record 40 of Set 3 | cidade velha
# Processing Record 41 of Set 3 | pujali
# Processing Record 42 of Set 3 | malanje
# Processing Record 43 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 3 | kingston
# Processing Record 45 of Set 3 | kodiak
# Processing Record 46 of Set 3 | bamboo flat
# Processing Record 47 of Set 3 | twon-brass
# Processing Record 48 of Set 3 | labytnangi
# Processing Record 49 of Set 3 | fuling
# Processing Record 0 of Set 4 | coquimbo
# Processing Record 1 of Set 4 | huazhou
# Processing Record 2 of Set 4 | tabou
# Processing Record 3 of Set 4 | suai
# City not found. Skipping...
# Processing Record 4 of Set 4 | bonthe
# Processing Record 5 of Set 4 | mugia
# Processing Record 6 of Set 4 | ghat
# Processing Record 7 of Set 4 | weno
# Processing Record 8 of Set 4 | papao
# Processing Record 9 of Set 4 | yelizovo
# Processing Record 10 of Set 4 | port lincoln
# Processing Record 11 of Set 4 | nabire
# Processing Record 12 of Set 4 | zyrya
# Processing Record 13 of Set 4 | uturoa
# Processing Record 14 of Set 4 | hermanus
# Processing Record 15 of Set 4 | iaciara
# Processing Record 16 of Set 4 | mili
# Processing Record 17 of Set 4 | nili
# Processing Record 18 of Set 4 | campoverde
# Processing Record 19 of Set 4 | westport
# Processing Record 20 of Set 4 | salinas
# Processing Record 21 of Set 4 | talnakh
# Processing Record 22 of Set 4 | anadyr
# Processing Record 23 of Set 4 | beirut
# Processing Record 24 of Set 4 | kapuskasing
# Processing Record 25 of Set 4 | banda aceh
# Processing Record 26 of Set 4 | ponta delgada
# Processing Record 27 of Set 4 | fonte boa
# Processing Record 28 of Set 4 | rizokarpaso
# Processing Record 29 of Set 4 | udachny
# Processing Record 30 of Set 4 | aleg
# Processing Record 31 of Set 4 | paidha
# Processing Record 32 of Set 4 | tobi village
# City not found. Skipping...
# Processing Record 33 of Set 4 | tazovsky
# Processing Record 34 of Set 4 | dhidhdhoo
# Processing Record 35 of Set 4 | olyokminsk
# Processing Record 36 of Set 4 | rio grande
# Processing Record 37 of Set 4 | kuching
# Processing Record 38 of Set 4 | kourou
# Processing Record 39 of Set 4 | paracuru
# Processing Record 40 of Set 4 | muriti
# Processing Record 41 of Set 4 | montemor-o-novo
# Processing Record 42 of Set 4 | stanley
# Processing Record 43 of Set 4 | arraial do cabo
# Processing Record 44 of Set 4 | nemuro
# Processing Record 45 of Set 4 | minas de matahambre
# City not found. Skipping...
# Processing Record 46 of Set 4 | carbonear
# Processing Record 47 of Set 4 | kodinsk
# Processing Record 48 of Set 4 | grass valley
# Processing Record 49 of Set 4 | eskisehir
# Processing Record 0 of Set 5 | tazacorte
# Processing Record 1 of Set 5 | saint-francois
# Processing Record 2 of Set 5 | goundam
# Processing Record 3 of Set 5 | gebeit
# Processing Record 4 of Set 5 | battambang
# Processing Record 5 of Set 5 | susuman
# Processing Record 6 of Set 5 | huarmey
# Processing Record 7 of Set 5 | spring creek
# Processing Record 8 of Set 5 | jamestown
# Processing Record 9 of Set 5 | edinburgh of the seven seas
# Processing Record 10 of Set 5 | tofol
# Processing Record 11 of Set 5 | felege neway
# Processing Record 12 of Set 5 | scarborough
# Processing Record 13 of Set 5 | papatowai
# Processing Record 14 of Set 5 | hasaki
# Processing Record 15 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 16 of Set 5 | padang
# Processing Record 17 of Set 5 | antsiranana
# Processing Record 18 of Set 5 | hermiston
# Processing Record 19 of Set 5 | mount isa
# Processing Record 20 of Set 5 | ginir
# Processing Record 21 of Set 5 | port elizabeth
# Processing Record 22 of Set 5 | umba
# Processing Record 23 of Set 5 | port augusta
# Processing Record 24 of Set 5 | dryden
# Processing Record 25 of Set 5 | kavaratti
# Processing Record 26 of Set 5 | swakopmund
# Processing Record 27 of Set 5 | luwuk
# Processing Record 28 of Set 5 | labasa
# Processing Record 29 of Set 5 | hotan
# Processing Record 30 of Set 5 | thinadhoo
# Processing Record 31 of Set 5 | miyanoura
# City not found. Skipping...
# Processing Record 32 of Set 5 | wusong
# Processing Record 33 of Set 5 | lusaka
# Processing Record 34 of Set 5 | ludwigsfelde
# Processing Record 35 of Set 5 | portland
# Processing Record 36 of Set 5 | detroit lakes
# Processing Record 37 of Set 5 | tranovaho
# City not found. Skipping...
# Processing Record 38 of Set 5 | el daein
# City not found. Skipping...
# Processing Record 39 of Set 5 | luanda
# Processing Record 40 of Set 5 | shalqar
# Processing Record 41 of Set 5 | shache
# Processing Record 42 of Set 5 | oodweyne
# Processing Record 43 of Set 5 | saipan
# Processing Record 44 of Set 5 | sorong
# Processing Record 45 of Set 5 | mukalla
# Processing Record 46 of Set 5 | portales
# Processing Record 47 of Set 5 | dwarka
# Processing Record 48 of Set 5 | tabas
# Processing Record 49 of Set 5 | quepos
# Processing Record 0 of Set 6 | ajaigarh
# Processing Record 1 of Set 6 | vingt cinq
# City not found. Skipping...
# Processing Record 2 of Set 6 | port blair
# Processing Record 3 of Set 6 | dudinka
# Processing Record 4 of Set 6 | la'ie
# Processing Record 5 of Set 6 | lospalos
# Processing Record 6 of Set 6 | rudsar
# Processing Record 7 of Set 6 | kotlas
# Processing Record 8 of Set 6 | anloga
# Processing Record 9 of Set 6 | safotu
# Processing Record 10 of Set 6 | abatskoye
# Processing Record 11 of Set 6 | kill devil hills
# Processing Record 12 of Set 6 | bereket
# Processing Record 13 of Set 6 | ancud
# Processing Record 14 of Set 6 | goynuk
# Processing Record 15 of Set 6 | bodo
# Processing Record 16 of Set 6 | port shepstone
# Processing Record 17 of Set 6 | sol'-iletsk
# Processing Record 18 of Set 6 | yen vinh
# Processing Record 19 of Set 6 | stephenville
# Processing Record 20 of Set 6 | sinabang
# Processing Record 21 of Set 6 | ashburton
# Processing Record 22 of Set 6 | tionk essil
# Processing Record 23 of Set 6 | ekibastuz
# Processing Record 24 of Set 6 | inarajan village
# Processing Record 25 of Set 6 | arroyo
# Processing Record 26 of Set 6 | nanchong
# Processing Record 27 of Set 6 | vila franca do campo
# Processing Record 28 of Set 6 | lompoc
# Processing Record 29 of Set 6 | borogontsy
# Processing Record 30 of Set 6 | tsiombe
# Processing Record 31 of Set 6 | fortaleza
# Processing Record 32 of Set 6 | la passe
# Processing Record 33 of Set 6 | bayan nur
# City not found. Skipping...
# Processing Record 34 of Set 6 | flin flon
# Processing Record 35 of Set 6 | wailua homesteads
# Processing Record 36 of Set 6 | muzayri'
# City not found. Skipping...
# Processing Record 37 of Set 6 | kilju
# Processing Record 38 of Set 6 | santa rosalia
# Processing Record 39 of Set 6 | singa
# Processing Record 40 of Set 6 | bull savanna
# Processing Record 41 of Set 6 | zima
# Processing Record 42 of Set 6 | niimi
# Processing Record 43 of Set 6 | forde
# Processing Record 44 of Set 6 | st. john's
# Processing Record 45 of Set 6 | east london
# Processing Record 46 of Set 6 | tambopata
# Processing Record 47 of Set 6 | tyukhtet
# Processing Record 48 of Set 6 | chinde
# Processing Record 49 of Set 6 | mount pearl
# Processing Record 0 of Set 7 | juye
# Processing Record 1 of Set 7 | san patricio
# Processing Record 2 of Set 7 | baruun-urt
# Processing Record 3 of Set 7 | sao miguel
# Processing Record 4 of Set 7 | lihue
# Processing Record 5 of Set 7 | anyang
# Processing Record 6 of Set 7 | lichtenburg
# Processing Record 7 of Set 7 | lebu
# Processing Record 8 of Set 7 | buritis
# Processing Record 9 of Set 7 | menaka
# Processing Record 10 of Set 7 | auki
# Processing Record 11 of Set 7 | revelstoke
# Processing Record 12 of Set 7 | dhuusamarreeb
# Processing Record 13 of Set 7 | simplicio mendes
# Processing Record 14 of Set 7 | santa marinella
# Processing Record 15 of Set 7 | sos'va
# Processing Record 16 of Set 7 | melfort
# Processing Record 17 of Set 7 | kenai
# Processing Record 18 of Set 7 | delta
# Processing Record 19 of Set 7 | rapar
# Processing Record 20 of Set 7 | tostado
# Processing Record 21 of Set 7 | hadibu
# Processing Record 22 of Set 7 | happy valley-goose bay
# Processing Record 23 of Set 7 | fort st. john
# Processing Record 24 of Set 7 | eyl
# Processing Record 25 of Set 7 | mogocha
# Processing Record 26 of Set 7 | nadym
# Processing Record 27 of Set 7 | panjab
# Processing Record 28 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 29 of Set 7 | al majaridah
# Processing Record 30 of Set 7 | kolasib
# Processing Record 31 of Set 7 | mata-utu
# Processing Record 32 of Set 7 | tunceli
# Processing Record 33 of Set 7 | kanganpur
# Processing Record 34 of Set 7 | olds
# Processing Record 35 of Set 7 | howard springs
# Processing Record 36 of Set 7 | richards bay
# Processing Record 37 of Set 7 | bouca
# Processing Record 38 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 39 of Set 7 | lerwick
# Processing Record 40 of Set 7 | kruisfontein
# Processing Record 41 of Set 7 | ambon
# Processing Record 42 of Set 7 | ahau
# City not found. Skipping...
# Processing Record 43 of Set 7 | dawesville
# Processing Record 44 of Set 7 | warwick
# Processing Record 45 of Set 7 | hammerfest
# Processing Record 46 of Set 7 | shingu
# Processing Record 47 of Set 7 | kamaishi
# Processing Record 48 of Set 7 | saldanha
# Processing Record 49 of Set 7 | virac
# Processing Record 0 of Set 8 | airuk
# Processing Record 1 of Set 8 | taoudenni
# Processing Record 2 of Set 8 | lesogorsk
# Processing Record 3 of Set 8 | kani keli
# Processing Record 4 of Set 8 | bafoulabe
# Processing Record 5 of Set 8 | francisco i. madero
# Processing Record 6 of Set 8 | tshabong
# Processing Record 7 of Set 8 | mahina
# Processing Record 8 of Set 8 | bria
# Processing Record 9 of Set 8 | dongola
# Processing Record 10 of Set 8 | cabo san lucas
# Processing Record 11 of Set 8 | touros
# Processing Record 12 of Set 8 | sao felix do xingu
# Processing Record 13 of Set 8 | betio village
# Processing Record 14 of Set 8 | fort bragg
# Processing Record 15 of Set 8 | puerto aysen
# Processing Record 16 of Set 8 | nogliki
# Processing Record 17 of Set 8 | iskateley
# Processing Record 18 of Set 8 | boyolangu
# Processing Record 19 of Set 8 | poso
# Processing Record 20 of Set 8 | igarka
# Processing Record 21 of Set 8 | san martin de los andes
# Processing Record 22 of Set 8 | iskushuban
# Processing Record 23 of Set 8 | carutapera
# Processing Record 24 of Set 8 | necochea
# Processing Record 25 of Set 8 | arkhangel'sk
# Processing Record 26 of Set 8 | machico
# Processing Record 27 of Set 8 | utrik
# Processing Record 28 of Set 8 | minab
# Processing Record 29 of Set 8 | itamaraca
# Processing Record 30 of Set 8 | geraldton
# Processing Record 31 of Set 8 | selfoss
# Processing Record 32 of Set 8 | popondetta
# Processing Record 33 of Set 8 | isle of lewis
# City not found. Skipping...
# Processing Record 34 of Set 8 | fuglafjordur
# Processing Record 35 of Set 8 | bayanhongor
# Processing Record 36 of Set 8 | saratamata
# City not found. Skipping...
# Processing Record 37 of Set 8 | bela
# Processing Record 38 of Set 8 | fagaras
# Processing Record 39 of Set 8 | broome
# Processing Record 40 of Set 8 | saint-philippe
# Processing Record 41 of Set 8 | luwingu
# Processing Record 42 of Set 8 | ketchikan
# Processing Record 43 of Set 8 | pombas
# Processing Record 44 of Set 8 | sarandi grande
# Processing Record 45 of Set 8 | saint croix
# Processing Record 46 of Set 8 | stiens
# Processing Record 47 of Set 8 | hassi messaoud
# Processing Record 48 of Set 8 | gusev
# Processing Record 49 of Set 8 | mineral wells
# Processing Record 0 of Set 9 | bechar
# Processing Record 1 of Set 9 | xinyuan
# Processing Record 2 of Set 9 | guadalajara
# Processing Record 3 of Set 9 | alesund
# Processing Record 4 of Set 9 | mossel bay
# Processing Record 5 of Set 9 | ust-kamenogorsk
# Processing Record 6 of Set 9 | villa dolores
# Processing Record 7 of Set 9 | nova sintra
# Processing Record 8 of Set 9 | gunjur
# Processing Record 9 of Set 9 | taman rajawali
# City not found. Skipping...
# Processing Record 10 of Set 9 | tafresh
# Processing Record 11 of Set 9 | mersa matruh
# Processing Record 12 of Set 9 | mejit
# Processing Record 13 of Set 9 | port isabel
# Processing Record 14 of Set 9 | labrador city
# Processing Record 15 of Set 9 | island harbour
# Processing Record 16 of Set 9 | pong nam ron
# Processing Record 17 of Set 9 | glace bay
# Processing Record 18 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 19 of Set 9 | macusani
# Processing Record 20 of Set 9 | bilajer
# Processing Record 21 of Set 9 | jakobstad
# Processing Record 22 of Set 9 | arar
# Processing Record 23 of Set 9 | baturaja
# Processing Record 24 of Set 9 | los andes
# Processing Record 25 of Set 9 | sao jose da coroa grande
# Processing Record 26 of Set 9 | cargados carajos
# City not found. Skipping...
# Processing Record 27 of Set 9 | praia
# Processing Record 28 of Set 9 | namibe
# Processing Record 29 of Set 9 | siwa oasis
# Processing Record 30 of Set 9 | khilok
# Processing Record 31 of Set 9 | sombrerete
# Processing Record 32 of Set 9 | oriximina
# Processing Record 33 of Set 9 | sola
# Processing Record 34 of Set 9 | kiruna
# Processing Record 35 of Set 9 | minas novas
# Processing Record 36 of Set 9 | puerto baquerizo moreno
# Processing Record 37 of Set 9 | alice springs
# Processing Record 38 of Set 9 | yorkton
# Processing Record 39 of Set 9 | fort mcmurray
# Processing Record 40 of Set 9 | amahai
# Processing Record 41 of Set 9 | sao miguel do araguaia
# Processing Record 42 of Set 9 | mersing
# Processing Record 43 of Set 9 | swan hill
# Processing Record 44 of Set 9 | brokopondo
# Processing Record 45 of Set 9 | nouadhibou
# Processing Record 46 of Set 9 | genhe
# Processing Record 47 of Set 9 | wotje
# Processing Record 48 of Set 9 | shimoda
# Processing Record 49 of Set 9 | yarmouth
# Processing Record 0 of Set 10 | malkapur
# Processing Record 1 of Set 10 | road town
# Processing Record 2 of Set 10 | trevelin
# Processing Record 3 of Set 10 | abraham's bay
# City not found. Skipping...
# Processing Record 4 of Set 10 | okha
# Processing Record 5 of Set 10 | san sebastian de la gomera
# Processing Record 6 of Set 10 | careiro da varzea
# Processing Record 7 of Set 10 | inhambane
# Processing Record 8 of Set 10 | askoy
# Processing Record 9 of Set 10 | waddan
# Processing Record 10 of Set 10 | port alfred
# Processing Record 11 of Set 10 | trincomalee
# Processing Record 12 of Set 10 | bubaque
# Processing Record 13 of Set 10 | qingnian
# Processing Record 14 of Set 10 | riachao do jacuipe
# Processing Record 15 of Set 10 | dunkerque
# Processing Record 16 of Set 10 | naantali
# Processing Record 17 of Set 10 | vernon
# Processing Record 18 of Set 10 | rampur
# Processing Record 19 of Set 10 | hirara
# Processing Record 20 of Set 10 | gonzalez
# Processing Record 21 of Set 10 | ellettsville
# Processing Record 22 of Set 10 | ricany
# Processing Record 23 of Set 10 | taourirt
# Processing Record 24 of Set 10 | nar'yan-mar
# Processing Record 25 of Set 10 | lazaro cardenas
# Processing Record 26 of Set 10 | kampot
# Processing Record 27 of Set 10 | agnibilekrou
# Processing Record 28 of Set 10 | bengkulu
# Processing Record 29 of Set 10 | metsamor
# Processing Record 30 of Set 10 | vigia
# Processing Record 31 of Set 10 | tual
# Processing Record 32 of Set 10 | shahr-e babak
# Processing Record 33 of Set 10 | korla
# Processing Record 34 of Set 10 | argo
# Processing Record 35 of Set 10 | konarka
# Processing Record 36 of Set 10 | deqen
# Processing Record 37 of Set 10 | bizerte
# Processing Record 38 of Set 10 | aykhal
# Processing Record 39 of Set 10 | vadso
# Processing Record 40 of Set 10 | montepuez
# Processing Record 41 of Set 10 | lusambo
# Processing Record 42 of Set 10 | pallasovka
# Processing Record 43 of Set 10 | makokou
# Processing Record 44 of Set 10 | pudasjarvi
# Processing Record 45 of Set 10 | duncan
# Processing Record 46 of Set 10 | brookings
# Processing Record 47 of Set 10 | prince rupert
# Processing Record 48 of Set 10 | energodar
# Processing Record 49 of Set 10 | mragowo
# Processing Record 0 of Set 11 | yuzhno-kurilsk
# Processing Record 1 of Set 11 | lubaczow
# Processing Record 2 of Set 11 | cestos city
# Processing Record 3 of Set 11 | daru
# Processing Record 4 of Set 11 | wotho
# Processing Record 5 of Set 11 | pasuquin
# Processing Record 6 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 7 of Set 11 | ebon
# Processing Record 8 of Set 11 | poronaysk
# Processing Record 9 of Set 11 | fuvahmulah
# City not found. Skipping...
# Processing Record 10 of Set 11 | oamaru
# Processing Record 11 of Set 11 | san carlos del zulia
# Processing Record 12 of Set 11 | tsimasham
# Processing Record 13 of Set 11 | puruliya
# Processing Record 14 of Set 11 | margate
# Processing Record 15 of Set 11 | kirishi
# Processing Record 16 of Set 11 | jinghong
# Processing Record 17 of Set 11 | pangody
# Processing Record 18 of Set 11 | tarauaca
# Processing Record 19 of Set 11 | nueva gerona
# Processing Record 20 of Set 11 | tete
# Processing Record 21 of Set 11 | lauro de freitas
# Processing Record 22 of Set 11 | salalah
# Processing Record 23 of Set 11 | cable beach
# City not found. Skipping...
# Processing Record 24 of Set 11 | paraiso
# Processing Record 25 of Set 11 | inirida
# Processing Record 26 of Set 11 | trondheim
# Processing Record 27 of Set 11 | monastir
# Processing Record 28 of Set 11 | kanuru
# Processing Record 29 of Set 11 | zaysan
# Processing Record 30 of Set 11 | ohara
# Processing Record 31 of Set 11 | chui
# Processing Record 32 of Set 11 | las palmas de gran canaria
# Processing Record 33 of Set 11 | thunder bay
# Processing Record 34 of Set 11 | 'ain boucif
# Processing Record 35 of Set 11 | beni saf
# Processing Record 36 of Set 11 | benguela
# Processing Record 37 of Set 11 | beledweyne
# Processing Record 38 of Set 11 | cave spring
# Processing Record 39 of Set 11 | unai
# Processing Record 40 of Set 11 | zelenogorsk
# Processing Record 41 of Set 11 | abu ghurayb
# Processing Record 42 of Set 11 | san borja
# Processing Record 43 of Set 11 | apiai
# Processing Record 44 of Set 11 | mudgee
# Processing Record 45 of Set 11 | twin falls
# Processing Record 46 of Set 11 | kamina
# Processing Record 47 of Set 11 | yerofey pavlovich
# Processing Record 48 of Set 11 | tongchuanshi
# Processing Record 49 of Set 11 | cerritos
# Processing Record 0 of Set 12 | warmbad
# Processing Record 1 of Set 12 | sao tome
# Processing Record 2 of Set 12 | new norfolk
# Processing Record 3 of Set 12 | naze
# Processing Record 4 of Set 12 | nampula
# Processing Record 5 of Set 12 | markovo
# Processing Record 6 of Set 12 | kimbo
# Processing Record 7 of Set 12 | nyurba
# Processing Record 8 of Set 12 | marsa alam
# Processing Record 9 of Set 12 | taltal
# Processing Record 10 of Set 12 | faro
# Processing Record 11 of Set 12 | colon
# Processing Record 12 of Set 12 | bukama
# Processing Record 13 of Set 12 | nacala
# Processing Record 14 of Set 12 | togur
# Processing Record 15 of Set 12 | coari
# Processing Record 16 of Set 12 | santa ana de yacuma
# Processing Record 17 of Set 12 | tinajo
# Processing Record 18 of Set 12 | araguaina
# Processing Record 19 of Set 12 | guazapa
# Processing Record 20 of Set 12 | coahuayana de hidalgo
# Processing Record 21 of Set 12 | haiku-pauwela
# Processing Record 22 of Set 12 | barentu
# Processing Record 23 of Set 12 | sarauli
# Processing Record 24 of Set 12 | kawthoung
# City not found. Skipping...
# Processing Record 25 of Set 12 | envira
# Processing Record 26 of Set 12 | woolgoolga
# Processing Record 27 of Set 12 | sao cristovao
# Processing Record 28 of Set 12 | robertsport
# Processing Record 29 of Set 12 | along
# Processing Record 30 of Set 12 | nogent-sur-seine
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
###QUERY### Why not returning? NB starter code = 577)

# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          551
# Lat           551
# Lng           551
# Max Temp      551
# Humidity      551
# Cloudiness    551
# Wind Speed    551
# Country       551
# Date          551
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           colby  39.3958 -101.0524     25.61        71           0
# 1            ta`u -14.2336 -169.5144     26.59        85          27
# 2  puerto natales -51.7236  -72.4875     -1.06        85          12
# 3          bardai  11.6500    7.2333     29.46        55          99
# 4      georgetown   5.4112  100.3354     28.97        79          20
#
#    Wind Speed Country        Date
# 0        4.12      US  1690122752
# 1        2.79      AS  1690122752
# 2        1.41      CL  1690122753
# 3        2.82      NG  1690122754
# 4        1.54      MY  1690122653

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                 colby  39.3958 -101.0524     25.61        71           0
# 1                  ta`u -14.2336 -169.5144     26.59        85          27
# 2        puerto natales -51.7236  -72.4875     -1.06        85          12
# 3                bardai  11.6500    7.2333     29.46        55          99
# 4            georgetown   5.4112  100.3354     28.97        79          20
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      US  1690122752
# 1              2.79      AS  1690122752
# 2              1.41      CL  1690122753
# 3              2.82      NG  1690122754
# 4              1.54      MY  1690122653

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitue vs. Temperature (2023-07-23)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Latitue vs. Humidity (2023-07-23)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitue vs. Cloudiness (2023-07-23)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitue vs. Wind Speed (2023-07-23)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
#### REFRESHER - completing lin regression standard way

#x_values = city_data_df['Lat']
#y_values = city_data_df['Max Temp']

#slope, intercept, rvalue, pvalue, stderr = linregress(x_values,y_values)
#regression = x_values * slope + intercept

#plt.scatter(x_values, y_values)
#plt.plot(x_values,regression, color="red")
#plt.xlabel('Latitude')
#plt.ylabel('Temperature')
#plt.title('Linear relationship for Latitude Vs. Temperature')
#plt.show()

# %%
# Define a function to create Linear Regression plots

def linear_regression(x_values,y_values, x_label, y_label, title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regression = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regression,"r-")
    plt.annotate(line_eq,(-50,100),fontsize=15,color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    print(f"The r-squared is: {rvalue**2:,.2f}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[(city_data_df["Lat"] >=0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             colby  39.3958 -101.0524     25.61        71           0
# 3            bardai  11.6500    7.2333     29.46        55          99
# 4        georgetown   5.4112  100.3354     28.97        79          20
# 8            badger  64.8000 -147.5333     20.95        80           0
# 9           iqaluit  63.7506  -68.5145      7.85        81          75
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      US  1690122752
# 3              2.82      NG  1690122754
# 4              1.54      MY  1690122653
# 8              2.57      US  1690122755
# 9              3.60      CA  1690122755

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[(city_data_df["Lat"] <=0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                     ta`u -14.2336 -169.5144     26.59        85          27
# 2           puerto natales -51.7236  -72.4875     -1.06        85          12
# 5            blackmans bay -43.0167  147.3167      8.62        79          86
# 6        port-aux-francais -49.3500   70.2167      5.95        85          99
# 7             puerto ayora  -0.7393  -90.3518     26.98        75          94
#
#          Wind Speed Country        Date
# City_ID
# 1              2.79      AS  1690122752
# 2              1.41      CL  1690122753
# 5              2.55      AU  1690122754
# 6             16.76      TF  1690122754
# 7              5.35      EC  1690122754

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"], 
                  "Latitude",
                  "Temperature",
                  "Temperature vs Latitude Linear Regression Plot (Northern Hemisphere)")
# Out:
# The r-squared is: 0.36

# %%
# Linear regression on Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"], 
                  "Latitude",
                  "Temperature",
                  "Temperature vs Latitude Linear Regression Plot (Southern Hemisphere)")
# Out:
# The r-squared is: 0.75

# %% [markdown]
# **Discussion about the linear relationship:** The above plots show a moderate correlation between temperature and latitude for the northern hemisphere (r value is greater than 0.35 but less than 0.7) and a strong correlation for the southern hemisphere (as r value is greater than 0.7).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Humidity"], 
                  "Latitude",
                  "Humidity",
                  "Humidity vs Latitude Linear Regression Plot (Northern Hemisphere)")
# Out:
# The r-squared is: 0.00

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Humidity"], 
                  "Latitude",
                  "Humidity",
                  "Humidity vs Latitude Linear Regression Plot (Southern Hemisphere)")


######## QUERY ######## why y= -0.45 etc showing on below but not other plots?
# Out:
# The r-squared is: 0.08

# %% [markdown]
# **Discussion about the linear relationship:** The above plots show there is a no correlation between humdity and latitude for either the Northern or Southern hemisphere (as r values 0, 0.08 respectively)

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"], 
                  "Latitude",
                  "Cloudiness",
                  "Cloudiness vs Latitude Linear Regression Plot (Northern Hemisphere)")
# Out:
# The r-squared is: 0.00

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"], 
                  "Latitude",
                  "Cloudiness",
                  "Cloudiness vs Latitude Linear Regression Plot (Southern Hemisphere)")
# Out:
# The r-squared is: 0.01

# %% [markdown]
# **Discussion about the linear relationship:** The above plots show there is a no correlation between cloudiness and latitude for either the Northern or Southern hemisphere (as r values 0, 0.01 respectively)

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"], 
                  "Latitude",
                  "Wind Speed",
                  "Wind Speed vs Latitude Linear Regression Plot (Northern Hemisphere)")
# Out:
# The r-squared is: 0.06

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"], 
                  "Latitude",
                  "Wind Speed",
                  "Wind Speed vs Latitude Linear Regression Plot (Southern Hemisphere)")
# Out:
# The r-squared is: 0.00

# %% [markdown]
# **Discussion about the linear relationship:** The above plots show there is a no correlation between wind speed and latitude for either the Northern or Southern hemisphere (as r values 0.06, 0 respectively)
