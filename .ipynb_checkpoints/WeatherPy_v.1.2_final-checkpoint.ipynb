# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 584

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    #######check aginst https://openweathermap.org/current
    
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()  

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | avarua
# Processing Record 2 of Set 1 | puerto armuelles
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | san fernando
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | iqaluit
# Processing Record 7 of Set 1 | porto velho
# Processing Record 8 of Set 1 | motueka
# Processing Record 9 of Set 1 | bilibino
# Processing Record 10 of Set 1 | kapuskasing
# Processing Record 11 of Set 1 | blackmans bay
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | hue
# Processing Record 15 of Set 1 | aasiaat
# Processing Record 16 of Set 1 | west island
# Processing Record 17 of Set 1 | aral
# Processing Record 18 of Set 1 | acapulco de juarez
# Processing Record 19 of Set 1 | malvan
# Processing Record 20 of Set 1 | san patricio
# Processing Record 21 of Set 1 | nuuk
# Processing Record 22 of Set 1 | ola
# Processing Record 23 of Set 1 | nallihan
# Processing Record 24 of Set 1 | puerto natales
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | kabalo
# Processing Record 27 of Set 1 | fale old settlement
# Processing Record 28 of Set 1 | rikaze
# Processing Record 29 of Set 1 | cidreira
# Processing Record 30 of Set 1 | waitangi
# Processing Record 31 of Set 1 | tolanaro
# Processing Record 32 of Set 1 | poronaysk
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | olonkinbyen
# Processing Record 35 of Set 1 | adamstown
# Processing Record 36 of Set 1 | gilgit
# Processing Record 37 of Set 1 | santana
# Processing Record 38 of Set 1 | ilulissat
# Processing Record 39 of Set 1 | anadyr
# Processing Record 40 of Set 1 | gadzhiyevo
# Processing Record 41 of Set 1 | atafu village
# Processing Record 42 of Set 1 | whitehorse
# Processing Record 43 of Set 1 | popondetta
# Processing Record 44 of Set 1 | colonia
# Processing Record 45 of Set 1 | enewetak
# Processing Record 46 of Set 1 | edinburgh of the seven seas
# Processing Record 47 of Set 1 | stanley
# Processing Record 48 of Set 1 | kachkanar
# Processing Record 49 of Set 1 | labuan
# Processing Record 50 of Set 1 | pacific grove
# Processing Record 0 of Set 2 | qaqortoq
# Processing Record 1 of Set 2 | kirensk
# Processing Record 2 of Set 2 | rudnichnyy
# Processing Record 3 of Set 2 | pokhara
# Processing Record 4 of Set 2 | ancud
# Processing Record 5 of Set 2 | keetmanshoop
# Processing Record 6 of Set 2 | yonggwang-up
# Processing Record 7 of Set 2 | vorgashor
# Processing Record 8 of Set 2 | saipan
# Processing Record 9 of Set 2 | lihue
# Processing Record 10 of Set 2 | longyearbyen
# Processing Record 11 of Set 2 | santa cruz
# Processing Record 12 of Set 2 | tiksi
# Processing Record 13 of Set 2 | ambon
# Processing Record 14 of Set 2 | asparuhovo
# Processing Record 15 of Set 2 | port-aux-francais
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | saudarkrokur
# Processing Record 18 of Set 2 | sao luis
# Processing Record 19 of Set 2 | kayes
# Processing Record 20 of Set 2 | uturoa
# Processing Record 21 of Set 2 | lompoc
# Processing Record 22 of Set 2 | ballston spa
# Processing Record 23 of Set 2 | papatowai
# Processing Record 24 of Set 2 | hwange
# Processing Record 25 of Set 2 | chicxulub puerto
# City not found. Skipping...
# Processing Record 26 of Set 2 | nsanje
# Processing Record 27 of Set 2 | kangding
# Processing Record 28 of Set 2 | menaka
# Processing Record 29 of Set 2 | maktar
# Processing Record 30 of Set 2 | streetly
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | san julian
# Processing Record 33 of Set 2 | namibe
# Processing Record 34 of Set 2 | toro
# Processing Record 35 of Set 2 | albany
# Processing Record 36 of Set 2 | petauke
# Processing Record 37 of Set 2 | geraldton
# Processing Record 38 of Set 2 | villa gesell
# Processing Record 39 of Set 2 | labrador city
# Processing Record 40 of Set 2 | ust'-ilimsk
# Processing Record 41 of Set 2 | gebeit
# Processing Record 42 of Set 2 | minas de marcona
# Processing Record 43 of Set 2 | astara
# Processing Record 44 of Set 2 | fabens
# Processing Record 45 of Set 2 | udachny
# Processing Record 46 of Set 2 | hailin
# Processing Record 47 of Set 2 | nova sintra
# Processing Record 48 of Set 2 | quellon
# Processing Record 49 of Set 2 | vieste
# Processing Record 0 of Set 3 | wladyslawowo
# Processing Record 1 of Set 3 | fort bragg
# Processing Record 2 of Set 3 | leava
# Processing Record 3 of Set 3 | the pas
# Processing Record 4 of Set 3 | lebu
# Processing Record 5 of Set 3 | talnakh
# Processing Record 6 of Set 3 | ulaangom
# Processing Record 7 of Set 3 | sept-iles
# Processing Record 8 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | fortaleza
# Processing Record 11 of Set 3 | baker city
# Processing Record 12 of Set 3 | port saint john's
# Processing Record 13 of Set 3 | save
# Processing Record 14 of Set 3 | kavaratti
# Processing Record 15 of Set 3 | ocos
# Processing Record 16 of Set 3 | constantia
# Processing Record 17 of Set 3 | jieyang
# Processing Record 18 of Set 3 | opuwo
# Processing Record 19 of Set 3 | holualoa
# Processing Record 20 of Set 3 | wa
# City not found. Skipping...
# Processing Record 21 of Set 3 | margaret river
# Processing Record 22 of Set 3 | remire-montjoly
# Processing Record 23 of Set 3 | meiganga
# Processing Record 24 of Set 3 | liberal
# Processing Record 25 of Set 3 | ratnagiri
# Processing Record 26 of Set 3 | zaterechnyy
# Processing Record 27 of Set 3 | tazacorte
# Processing Record 28 of Set 3 | lerwick
# Processing Record 29 of Set 3 | lusambo
# Processing Record 30 of Set 3 | port macquarie
# Processing Record 31 of Set 3 | port mathurin
# Processing Record 32 of Set 3 | okha
# Processing Record 33 of Set 3 | balqash
# Processing Record 34 of Set 3 | nhamunda
# Processing Record 35 of Set 3 | axim
# Processing Record 36 of Set 3 | ushuaia
# Processing Record 37 of Set 3 | chonchi
# Processing Record 38 of Set 3 | vila franca do campo
# Processing Record 39 of Set 3 | owando
# Processing Record 40 of Set 3 | badger
# Processing Record 41 of Set 3 | aubenas
# Processing Record 42 of Set 3 | vilyuchinsk
# Processing Record 43 of Set 3 | sumbal
# Processing Record 44 of Set 3 | kastsyukovichy
# Processing Record 45 of Set 3 | ahau
# City not found. Skipping...
# Processing Record 46 of Set 3 | mili
# Processing Record 47 of Set 3 | winsted
# Processing Record 48 of Set 3 | college
# Processing Record 49 of Set 3 | senirkent
# Processing Record 0 of Set 4 | susuman
# Processing Record 1 of Set 4 | thompson
# Processing Record 2 of Set 4 | thunder bay
# Processing Record 3 of Set 4 | dahlonega
# Processing Record 4 of Set 4 | zhangatas
# Processing Record 5 of Set 4 | bubaque
# Processing Record 6 of Set 4 | pauini
# Processing Record 7 of Set 4 | al harithah
# Processing Record 8 of Set 4 | cabo san lucas
# Processing Record 9 of Set 4 | nogliki
# Processing Record 10 of Set 4 | valle de la pascua
# Processing Record 11 of Set 4 | utrik
# Processing Record 12 of Set 4 | west busselton
# City not found. Skipping...
# Processing Record 13 of Set 4 | guatrache
# Processing Record 14 of Set 4 | bamboo flat
# Processing Record 15 of Set 4 | ribeira grande
# Processing Record 16 of Set 4 | severo-yeniseyskiy
# Processing Record 17 of Set 4 | hammerfest
# Processing Record 18 of Set 4 | villa union
# Processing Record 19 of Set 4 | hauterive
# Processing Record 20 of Set 4 | asau
# Processing Record 21 of Set 4 | tarawa
# Processing Record 22 of Set 4 | bayanaul
# Processing Record 23 of Set 4 | al wajh
# Processing Record 24 of Set 4 | shalqar
# Processing Record 25 of Set 4 | nishinoomote
# Processing Record 26 of Set 4 | kataragama
# City not found. Skipping...
# Processing Record 27 of Set 4 | natal
# Processing Record 28 of Set 4 | taro
# Processing Record 29 of Set 4 | codrington
# Processing Record 30 of Set 4 | ulanhot
# Processing Record 31 of Set 4 | bandon
# Processing Record 32 of Set 4 | strabane
# Processing Record 33 of Set 4 | nemuro
# Processing Record 34 of Set 4 | taiohae
# City not found. Skipping...
# Processing Record 35 of Set 4 | mount isa
# Processing Record 36 of Set 4 | st. john's
# Processing Record 37 of Set 4 | bridgewater
# Processing Record 38 of Set 4 | ust-nera
# Processing Record 39 of Set 4 | isafjordur
# Processing Record 40 of Set 4 | abraham's bay
# City not found. Skipping...
# Processing Record 41 of Set 4 | pinarbasi
# Processing Record 42 of Set 4 | spring creek
# Processing Record 43 of Set 4 | olinda
# Processing Record 44 of Set 4 | port elizabeth
# Processing Record 45 of Set 4 | heunghae
# Processing Record 46 of Set 4 | plastun
# Processing Record 47 of Set 4 | bredasdorp
# Processing Record 48 of Set 4 | tibu
# Processing Record 49 of Set 4 | iskateley
# Processing Record 0 of Set 5 | leh
# Processing Record 1 of Set 5 | praia da vitoria
# Processing Record 2 of Set 5 | hadibu
# Processing Record 3 of Set 5 | yagry
# City not found. Skipping...
# Processing Record 4 of Set 5 | gafsa
# Processing Record 5 of Set 5 | zhanaozen
# Processing Record 6 of Set 5 | ust'-barguzin
# Processing Record 7 of Set 5 | 'ohonua
# City not found. Skipping...
# Processing Record 8 of Set 5 | wailua homesteads
# Processing Record 9 of Set 5 | hawaiian paradise park
# Processing Record 10 of Set 5 | cogealac
# Processing Record 11 of Set 5 | nuevo ideal
# Processing Record 12 of Set 5 | dunedin
# Processing Record 13 of Set 5 | melito di porto salvo
# Processing Record 14 of Set 5 | sao joao da barra
# Processing Record 15 of Set 5 | toliara
# Processing Record 16 of Set 5 | katsuura
# Processing Record 17 of Set 5 | saguenay
# Processing Record 18 of Set 5 | jamestown
# Processing Record 19 of Set 5 | kone
# Processing Record 20 of Set 5 | great falls
# Processing Record 21 of Set 5 | hithadhoo
# Processing Record 22 of Set 5 | baiti
# Processing Record 23 of Set 5 | nar'yan-mar
# Processing Record 24 of Set 5 | jingdezhen
# Processing Record 25 of Set 5 | narrabri
# Processing Record 26 of Set 5 | laascaanood
# Processing Record 27 of Set 5 | celestun
# Processing Record 28 of Set 5 | punta del este
# Processing Record 29 of Set 5 | toga village
# City not found. Skipping...
# Processing Record 30 of Set 5 | yanam
# Processing Record 31 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 32 of Set 5 | kuala terengganu
# Processing Record 33 of Set 5 | kulhudhuffushi
# Processing Record 34 of Set 5 | san antonio de pale
# Processing Record 35 of Set 5 | khovd
# Processing Record 36 of Set 5 | eagle point
# Processing Record 37 of Set 5 | saint ann's bay
# Processing Record 38 of Set 5 | afaahiti
# Processing Record 39 of Set 5 | tchollire
# Processing Record 40 of Set 5 | dudinka
# Processing Record 41 of Set 5 | morehead city
# Processing Record 42 of Set 5 | saint-philippe
# Processing Record 43 of Set 5 | faya-largeau
# Processing Record 44 of Set 5 | east london
# Processing Record 45 of Set 5 | bella union
# Processing Record 46 of Set 5 | mount gambier
# Processing Record 47 of Set 5 | meulaboh
# Processing Record 48 of Set 5 | villa la angostura
# Processing Record 49 of Set 5 | garissa
# Processing Record 0 of Set 6 | la ronge
# Processing Record 1 of Set 6 | pathein
# Processing Record 2 of Set 6 | leongatha
# Processing Record 3 of Set 6 | ngerengere
# Processing Record 4 of Set 6 | campamento
# Processing Record 5 of Set 6 | lagunas
# Processing Record 6 of Set 6 | hengyang
# Processing Record 7 of Set 6 | novodvinsk
# Processing Record 8 of Set 6 | bodo
# Processing Record 9 of Set 6 | tindouf
# Processing Record 10 of Set 6 | kimbe
# Processing Record 11 of Set 6 | port augusta
# Processing Record 12 of Set 6 | kishorganj
# Processing Record 13 of Set 6 | mamuju
# Processing Record 14 of Set 6 | yaren
# Processing Record 15 of Set 6 | carnarvon
# Processing Record 16 of Set 6 | guanica
# Processing Record 17 of Set 6 | karratha
# Processing Record 18 of Set 6 | carauari
# Processing Record 19 of Set 6 | blacksburg
# Processing Record 20 of Set 6 | el bolson
# Processing Record 21 of Set 6 | bochum
# Processing Record 22 of Set 6 | driefontein
# Processing Record 23 of Set 6 | zhangjiakou
# Processing Record 24 of Set 6 | la'ie
# Processing Record 25 of Set 6 | puerto deseado
# Processing Record 26 of Set 6 | happy valley-goose bay
# Processing Record 27 of Set 6 | howard springs
# Processing Record 28 of Set 6 | saint-francois
# Processing Record 29 of Set 6 | dryden
# Processing Record 30 of Set 6 | rongelap
# Processing Record 31 of Set 6 | flying fish cove
# Processing Record 32 of Set 6 | arish
# Processing Record 33 of Set 6 | tobelo
# Processing Record 34 of Set 6 | dinar
# Processing Record 35 of Set 6 | atasu
# Processing Record 36 of Set 6 | veseloyarsk
# Processing Record 37 of Set 6 | aykhal
# Processing Record 38 of Set 6 | mogadishu
# Processing Record 39 of Set 6 | yamada
# Processing Record 40 of Set 6 | dvurechensk
# Processing Record 41 of Set 6 | gaiman
# Processing Record 42 of Set 6 | kapa'a
# Processing Record 43 of Set 6 | sinazongwe
# Processing Record 44 of Set 6 | puerto princesa
# Processing Record 45 of Set 6 | kyshtovka
# Processing Record 46 of Set 6 | barrouallie
# Processing Record 47 of Set 6 | carbonear
# Processing Record 48 of Set 6 | keflavik
# Processing Record 49 of Set 6 | pisco
# Processing Record 0 of Set 7 | polyarnyy
# Processing Record 1 of Set 7 | new norfolk
# Processing Record 2 of Set 7 | altay
# Processing Record 3 of Set 7 | queenstown
# Processing Record 4 of Set 7 | invercargill
# Processing Record 5 of Set 7 | zhezqazghan
# Processing Record 6 of Set 7 | port alfred
# Processing Record 7 of Set 7 | gannan
# Processing Record 8 of Set 7 | tommot
# Processing Record 9 of Set 7 | sao bento
# Processing Record 10 of Set 7 | kalemie
# Processing Record 11 of Set 7 | san antonio oeste
# Processing Record 12 of Set 7 | hepo
# Processing Record 13 of Set 7 | dubbo
# Processing Record 14 of Set 7 | port lincoln
# Processing Record 15 of Set 7 | veracruz
# Processing Record 16 of Set 7 | wotho
# Processing Record 17 of Set 7 | hamilton
# Processing Record 18 of Set 7 | quetigny
# Processing Record 19 of Set 7 | hrubieszow
# Processing Record 20 of Set 7 | kamaishi
# Processing Record 21 of Set 7 | harlan
# Processing Record 22 of Set 7 | fort st. john
# Processing Record 23 of Set 7 | heniches'k
# Processing Record 24 of Set 7 | petropavlovsk-kamchatsky
# Processing Record 25 of Set 7 | new plymouth
# Processing Record 26 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 27 of Set 7 | semnan
# Processing Record 28 of Set 7 | ocean city
# Processing Record 29 of Set 7 | abepura
# Processing Record 30 of Set 7 | peterhead
# Processing Record 31 of Set 7 | caucete
# Processing Record 32 of Set 7 | padang
# Processing Record 33 of Set 7 | naranjito
# Processing Record 34 of Set 7 | griffith
# Processing Record 35 of Set 7 | taichung
# Processing Record 36 of Set 7 | egilsstadir
# Processing Record 37 of Set 7 | dalandzadgad
# Processing Record 38 of Set 7 | saint-pierre
# Processing Record 39 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 7 | pionerskiy
# Processing Record 41 of Set 7 | salalah
# Processing Record 42 of Set 7 | burang
# Processing Record 43 of Set 7 | portland
# Processing Record 44 of Set 7 | nuku'alofa
# Processing Record 45 of Set 7 | antofagasta
# Processing Record 46 of Set 7 | ismayilli
# Processing Record 47 of Set 7 | el calafate
# Processing Record 48 of Set 7 | vilyuysk
# Processing Record 49 of Set 7 | horta
# Processing Record 0 of Set 8 | laguna
# Processing Record 1 of Set 8 | chegdomyn
# Processing Record 2 of Set 8 | kedrovyy
# Processing Record 3 of Set 8 | nabire
# Processing Record 4 of Set 8 | mejit
# Processing Record 5 of Set 8 | alice springs
# Processing Record 6 of Set 8 | ketchikan
# Processing Record 7 of Set 8 | musay'id
# City not found. Skipping...
# Processing Record 8 of Set 8 | decazeville
# Processing Record 9 of Set 8 | robore
# Processing Record 10 of Set 8 | guerrero negro
# Processing Record 11 of Set 8 | glazunovka
# Processing Record 12 of Set 8 | bollnas
# Processing Record 13 of Set 8 | baruun-urt
# Processing Record 14 of Set 8 | manali
# Processing Record 15 of Set 8 | bang saphan
# Processing Record 16 of Set 8 | timbuktu
# Processing Record 17 of Set 8 | horki
# Processing Record 18 of Set 8 | bikenibeu village
# Processing Record 19 of Set 8 | tanjung selor
# City not found. Skipping...
# Processing Record 20 of Set 8 | santa ana
# Processing Record 21 of Set 8 | elliot lake
# Processing Record 22 of Set 8 | odda
# Processing Record 23 of Set 8 | argo
# Processing Record 24 of Set 8 | divnogorsk
# Processing Record 25 of Set 8 | kem'
# Processing Record 26 of Set 8 | hirara
# Processing Record 27 of Set 8 | ramban
# Processing Record 28 of Set 8 | calama
# Processing Record 29 of Set 8 | morant bay
# Processing Record 30 of Set 8 | patterson
# Processing Record 31 of Set 8 | ilhabela
# Processing Record 32 of Set 8 | gaspe
# Processing Record 33 of Set 8 | caratinga
# Processing Record 34 of Set 8 | bandarbeyla
# Processing Record 35 of Set 8 | huangpi
# Processing Record 36 of Set 8 | tawau
# Processing Record 37 of Set 8 | dhidhdhoo
# Processing Record 38 of Set 8 | ponta delgada
# Processing Record 39 of Set 8 | luderitz
# Processing Record 40 of Set 8 | ba
# City not found. Skipping...
# Processing Record 41 of Set 8 | inarajan village
# Processing Record 42 of Set 8 | stolin
# Processing Record 43 of Set 8 | san sebastian de la gomera
# Processing Record 44 of Set 8 | arraial do cabo
# Processing Record 45 of Set 8 | taulaga
# Processing Record 46 of Set 8 | kutum
# Processing Record 47 of Set 8 | kashgar
# Processing Record 48 of Set 8 | camayenne
# Processing Record 49 of Set 8 | puerto cabezas
# Processing Record 0 of Set 9 | tura
# Processing Record 1 of Set 9 | york
# Processing Record 2 of Set 9 | bac lieu
# Processing Record 3 of Set 9 | srivardhan
# Processing Record 4 of Set 9 | viana
# Processing Record 5 of Set 9 | tongren
# Processing Record 6 of Set 9 | pasni
# Processing Record 7 of Set 9 | howrah
# Processing Record 8 of Set 9 | elizabethton
# Processing Record 9 of Set 9 | saldanha
# Processing Record 10 of Set 9 | antalaha
# Processing Record 11 of Set 9 | praia
# Processing Record 12 of Set 9 | hakui
# Processing Record 13 of Set 9 | energetik
# Processing Record 14 of Set 9 | sao felix do xingu
# Processing Record 15 of Set 9 | touros
# Processing Record 16 of Set 9 | zouerate
# Processing Record 17 of Set 9 | castillos
# Processing Record 18 of Set 9 | mokrous
# Processing Record 19 of Set 9 | itoman
# Processing Record 20 of Set 9 | lucapa
# Processing Record 21 of Set 9 | xai-xai
# Processing Record 22 of Set 9 | hotan
# Processing Record 23 of Set 9 | vila velha
# Processing Record 24 of Set 9 | arar
# Processing Record 25 of Set 9 | coari
# Processing Record 26 of Set 9 | tabou
# Processing Record 27 of Set 9 | boda
# Processing Record 28 of Set 9 | sisimiut
# Processing Record 29 of Set 9 | mhamid
# Processing Record 30 of Set 9 | kifri
# Processing Record 31 of Set 9 | peace river
# Processing Record 32 of Set 9 | araruna
# Processing Record 33 of Set 9 | harper
# Processing Record 34 of Set 9 | hercules
# Processing Record 35 of Set 9 | kahror pakka
# Processing Record 36 of Set 9 | isangel
# Processing Record 37 of Set 9 | alvaraes
# Processing Record 38 of Set 9 | praya
# Processing Record 39 of Set 9 | khandyga
# Processing Record 40 of Set 9 | posto fiscal rolim de moura
# Processing Record 41 of Set 9 | tirhanimine
# Processing Record 42 of Set 9 | la passe
# Processing Record 43 of Set 9 | tazovsky
# Processing Record 44 of Set 9 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 45 of Set 9 | northam
# Processing Record 46 of Set 9 | kerikeri
# Processing Record 47 of Set 9 | yelizovo
# Processing Record 48 of Set 9 | broome
# Processing Record 49 of Set 9 | totness
# Processing Record 0 of Set 10 | bardai
# Processing Record 1 of Set 10 | kingston
# Processing Record 2 of Set 10 | chibougamau
# Processing Record 3 of Set 10 | pangai
# Processing Record 4 of Set 10 | al majaridah
# Processing Record 5 of Set 10 | tame
# Processing Record 6 of Set 10 | port glaud
# City not found. Skipping...
# Processing Record 7 of Set 10 | lata
# Processing Record 8 of Set 10 | yungay
# Processing Record 9 of Set 10 | ust'-kulom
# Processing Record 10 of Set 10 | laayoune
# Processing Record 11 of Set 10 | slave lake
# Processing Record 12 of Set 10 | seguela
# Processing Record 13 of Set 10 | jand
# Processing Record 14 of Set 10 | prado
# Processing Record 15 of Set 10 | kudymkar
# Processing Record 16 of Set 10 | ndjole
# Processing Record 17 of Set 10 | dong ha
# Processing Record 18 of Set 10 | misratah
# Processing Record 19 of Set 10 | noshiro
# Processing Record 20 of Set 10 | colares
# Processing Record 21 of Set 10 | ouellah
# City not found. Skipping...
# Processing Record 22 of Set 10 | mpraeso
# Processing Record 23 of Set 10 | nikol'sk
# Processing Record 24 of Set 10 | den burg
# Processing Record 25 of Set 10 | alofi
# Processing Record 26 of Set 10 | cargados carajos
# City not found. Skipping...
# Processing Record 27 of Set 10 | puerto lempira
# Processing Record 28 of Set 10 | panjakent
# Processing Record 29 of Set 10 | shevchenko
# Processing Record 30 of Set 10 | lionel town
# Processing Record 31 of Set 10 | olgii
# City not found. Skipping...
# Processing Record 32 of Set 10 | kavieng
# Processing Record 33 of Set 10 | ciudad madero
# Processing Record 34 of Set 10 | barah
# Processing Record 35 of Set 10 | lagoa
# Processing Record 36 of Set 10 | waslala
# Processing Record 37 of Set 10 | auki
# Processing Record 38 of Set 10 | kaspiyskiy
# Processing Record 39 of Set 10 | bichura
# Processing Record 40 of Set 10 | aykol
# City not found. Skipping...
# Processing Record 41 of Set 10 | dul'durga
# Processing Record 42 of Set 10 | sihanoukville
# Processing Record 43 of Set 10 | takoradi
# Processing Record 44 of Set 10 | avrig
# Processing Record 45 of Set 10 | harran
# Processing Record 46 of Set 10 | seaside
# Processing Record 47 of Set 10 | strelka
# Processing Record 48 of Set 10 | marshall
# Processing Record 49 of Set 10 | pangyan
# Processing Record 0 of Set 11 | murghob
# Processing Record 1 of Set 11 | itaituba
# Processing Record 2 of Set 11 | san luis de la loma
# Processing Record 3 of Set 11 | flin flon
# Processing Record 4 of Set 11 | sarangani
# Processing Record 5 of Set 11 | kourou
# Processing Record 6 of Set 11 | klaksvik
# Processing Record 7 of Set 11 | broken hill
# Processing Record 8 of Set 11 | esmeraldas
# Processing Record 9 of Set 11 | lucea
# Processing Record 10 of Set 11 | shakhun'ya
# Processing Record 11 of Set 11 | noumea
# Processing Record 12 of Set 11 | tharangambadi
# Processing Record 13 of Set 11 | nikel
# Processing Record 14 of Set 11 | moussoro
# Processing Record 15 of Set 11 | juba
# Processing Record 16 of Set 11 | isiro
# Processing Record 17 of Set 11 | tsaratanana
# Processing Record 18 of Set 11 | reggane
# Processing Record 19 of Set 11 | newman
# Processing Record 20 of Set 11 | pangkalpinang
# Processing Record 21 of Set 11 | lautoka
# Processing Record 22 of Set 11 | kudahuvadhoo
# Processing Record 23 of Set 11 | grand-bassam
# Processing Record 24 of Set 11 | zangguy
# City not found. Skipping...
# Processing Record 25 of Set 11 | anloga
# Processing Record 26 of Set 11 | blenheim
# Processing Record 27 of Set 11 | palmer
# Processing Record 28 of Set 11 | mijdrecht
# Processing Record 29 of Set 11 | bousso
# Processing Record 30 of Set 11 | puerto ayacucho
# Processing Record 31 of Set 11 | brigantine
# Processing Record 32 of Set 11 | al burayqah
# Processing Record 33 of Set 11 | beppu
# Processing Record 34 of Set 11 | zhumysker
# Processing Record 35 of Set 11 | klyuchi
# Processing Record 36 of Set 11 | barcelos
# Processing Record 37 of Set 11 | seosan
# Processing Record 38 of Set 11 | ust'-kut
# Processing Record 39 of Set 11 | gornozavodsk
# Processing Record 40 of Set 11 | prince george
# Processing Record 41 of Set 11 | illizi
# Processing Record 42 of Set 11 | brookings
# Processing Record 43 of Set 11 | espargos
# City not found. Skipping...
# Processing Record 44 of Set 11 | bonthe
# Processing Record 45 of Set 11 | mar del plata
# Processing Record 46 of Set 11 | ad dabbah
# Processing Record 47 of Set 11 | sol'-iletsk
# Processing Record 48 of Set 11 | warrenton
# Processing Record 49 of Set 11 | rio preto da eva
# Processing Record 0 of Set 12 | krasnokamsk
# Processing Record 1 of Set 12 | port moresby
# Processing Record 2 of Set 12 | jilib
# Processing Record 3 of Set 12 | acarau
# Processing Record 4 of Set 12 | tual
# Processing Record 5 of Set 12 | butte
# Processing Record 6 of Set 12 | igarka
# Processing Record 7 of Set 12 | cacheu
# Processing Record 8 of Set 12 | selfoss
# Processing Record 9 of Set 12 | shambu
# Processing Record 10 of Set 12 | oranjemund
# Processing Record 11 of Set 12 | uige
# Processing Record 12 of Set 12 | oyama
# Processing Record 13 of Set 12 | grojec
# Processing Record 14 of Set 12 | noyabrsk
# Processing Record 15 of Set 12 | rodna
# Processing Record 16 of Set 12 | boguchany
# Processing Record 17 of Set 12 | malango
# Processing Record 18 of Set 12 | undurkhaan
# Processing Record 19 of Set 12 | mando
# Processing Record 20 of Set 12 | kilifi
# Processing Record 21 of Set 12 | belmonte
# Processing Record 22 of Set 12 | al 'aziziyah
# Processing Record 23 of Set 12 | kailua-kona
# Processing Record 24 of Set 12 | bathurst
# Processing Record 25 of Set 12 | alo
# Processing Record 26 of Set 12 | liupanshui
# City not found. Skipping...
# Processing Record 27 of Set 12 | ulladulla
# Processing Record 28 of Set 12 | mahina
# Processing Record 29 of Set 12 | kuta
# Processing Record 30 of Set 12 | beyneu
# Processing Record 31 of Set 12 | colachel
# Processing Record 32 of Set 12 | el obeid
# Processing Record 33 of Set 12 | shache
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          558
# Lat           558
# Lng           558
# Max Temp      558
# Humidity      558
# Cloudiness    558
# Wind Speed    558
# Country       558
# Date          558
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            avarua -21.2078 -159.7750     25.03       100          75
# 1  puerto armuelles   8.2833  -82.8667     31.99        77          92
# 2            bethel  41.3712  -73.4140     30.41        47           0
# 3      san fernando  15.0286  120.6898     25.85        91         100
# 4         grytviken -54.2811  -36.5092     -6.70        73          15
#
#    Wind Speed Country        Date
# 0        3.60      CK  1690136541
# 1        1.34      PA  1690136541
# 2        4.12      US  1690136542
# 3        0.42      PH  1690136542
# 4        4.67      GS  1690136542

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                  avarua -21.2078 -159.7750     25.03       100          75
# 1        puerto armuelles   8.2833  -82.8667     31.99        77          92
# 2                  bethel  41.3712  -73.4140     30.41        47           0
# 3            san fernando  15.0286  120.6898     25.85        91         100
# 4               grytviken -54.2811  -36.5092     -6.70        73          15
#
#          Wind Speed Country        Date
# City_ID
# 0              3.60      CK  1690136541
# 1              1.34      PA  1690136541
# 2              4.12      US  1690136542
# 3              0.42      PH  1690136542
# 4              4.67      GS  1690136542

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Max Latitue vs. Temperature (2023-07-23)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.title("City Latitue vs. Humidity (2023-07-23)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.title("City Latitue vs. Cloudiness (2023-07-23)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"])

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.title("City Latitue vs. Wind Speed (2023-07-23)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression(x_values,y_values, x_label, y_label, xy_coords, title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regression = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_values,y_values)
    plt.plot(x_values, regression,"r-")
    plt.annotate(line_eq, (xy_coords), fontsize=15,color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    print(f"The r-squared is: {rvalue**2:,.2f}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[(city_data_df["Lat"] >=0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        puerto armuelles   8.2833  -82.8667     31.99        77          92
# 2                  bethel  41.3712  -73.4140     30.41        47           0
# 3            san fernando  15.0286  120.6898     25.85        91         100
# 5                 iqaluit  63.7506  -68.5145      9.85        71          40
# 8                bilibino  68.0546  166.4372     16.45        69         100
#
#          Wind Speed Country        Date
# City_ID
# 1              1.34      PA  1690136541
# 2              4.12      US  1690136542
# 3              0.42      PH  1690136542
# 5              5.36      CA  1690136542
# 8              0.92      RU  1690136542

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[(city_data_df["Lat"] <=0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               avarua -21.2078 -159.7750     25.03       100          75
# 4            grytviken -54.2811  -36.5092     -6.70        73          15
# 6          porto velho  -8.7619  -63.9039     34.03        49           0
# 7              motueka -41.1333  173.0167      8.39        90          94
# 10       blackmans bay -43.0167  147.3167      9.18        78          92
#
#          Wind Speed Country        Date
# City_ID
# 0              3.60      CK  1690136541
# 4              4.67      GS  1690136542
# 6              2.57      BR  1690136332
# 7              2.58      NZ  1690136542
# 10             1.89      AU  1690136543

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Max Temp"], 
                  "Latitude",
                  "Temperature",
                  (0,40),
                  "Temperature vs Latitude Linear Regression Plot (Northern Hemisphere)")
# Out:
# The r-squared is: 0.38

# %%
# Linear regression on Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Max Temp"], 
                  "Latitude",
                  "Temperature",
                  (-50,35),
                  "Temperature vs Latitude Linear Regression Plot (Southern Hemisphere)")
# Out:
# The r-squared is: 0.77

# %% [markdown]
# **Discussion about the linear relationship:** The above plots show a moderate correlation between temperature and latitude for the northern hemisphere (r value is greater than 0.35 but less than 0.7) and a strong correlation for the southern hemisphere (as r value is greater than 0.7).

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Humidity"], 
                  "Latitude",
                  "Humidity",
                  (0,100),
                  "Humidity vs Latitude Linear Regression Plot (Northern Hemisphere)")
# Out:
# The r-squared is: 0.00

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Humidity"], 
                  "Latitude",
                  "Humidity",
                  (0,100),
                  "Humidity vs Latitude Linear Regression Plot (Southern Hemisphere)")
# Out:
# The r-squared is: 0.07

# %% [markdown]
# **Discussion about the linear relationship:** The above plots show there is a no correlation between humdity and latitude for either the Northern or Southern hemisphere (as r values 0, 0.08 respectively)

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Cloudiness"], 
                  "Latitude",
                  "Cloudiness",
                  (0,100),
                  "Cloudiness vs Latitude Linear Regression Plot (Northern Hemisphere)")
# Out:
# The r-squared is: 0.00

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Cloudiness"], 
                  "Latitude",
                  "Cloudiness",
                  (0,100),
                  "Cloudiness vs Latitude Linear Regression Plot (Southern Hemisphere)")
# Out:
# The r-squared is: 0.02

# %% [markdown]
# **Discussion about the linear relationship:** The above plots show there is a no correlation between cloudiness and latitude for either the Northern or Southern hemisphere (as r values 0, 0.01 respectively)

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regression(northern_hemi_df["Lat"],northern_hemi_df["Wind Speed"], 
                  "Latitude",
                  "Wind Speed",
                  (0,12),
                  "Wind Speed vs Latitude Linear Regression Plot (Northern Hemisphere)")
# Out:
# The r-squared is: 0.04

# %%
# Southern Hemisphere
linear_regression(southern_hemi_df["Lat"],southern_hemi_df["Wind Speed"], 
                  "Latitude",
                  "Wind Speed",
                  (0,17.5),
                  "Wind Speed vs Latitude Linear Regression Plot (Southern Hemisphere)")
# Out:
# The r-squared is: 0.00

# %% [markdown]
# **Discussion about the linear relationship:** The above plots show there is a no correlation between wind speed and latitude for either the Northern or Southern hemisphere (as r values 0.06, 0 respectively)
